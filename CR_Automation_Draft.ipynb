# %%
import pandas as pd
import openpyxl
import os
from openai import OpenAI
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 4
#       2 import openpyxl
#       3 import os
# ----> 4 from openai import OpenAI
#
# ModuleNotFoundError: No module named 'openai'

# %%
# !pip install openai
# Out:
# ...
#   WARNING: Failed to write executable - trying to use .deleteme logic
# ERROR: Could not install packages due to an OSError: [WinError 2] The system cannot find the file specified: 'C:\\Python312\\Scripts\\httpx.exe' -> 'C:\\Python312\\Scripts\\httpx.exe.deleteme'
#
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Using cached openai-1.46.1-py3-none-any.whl.metadata (24 kB)
# ...
#   Using cached anyio-4.5.0-py3-none-any.whl.metadata (4.7 kB)
# ...
#   Using cached httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# ...
# Using cached openai-1.46.1-py3-none-any.whl (375 kB)
# Using cached anyio-4.5.0-py3-none-any.whl (89 kB)
# Using cached httpx-0.27.2-py3-none-any.whl (76 kB)
# Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# ...

# %%
data = "The business driver is to refine the metadata and to extract the attachments from eLN experiment pdf files into EDB S3 Refine Bucket from LOXO-Signals and DICE eLN experiment data which is available in S3 Raw Bucket. The finalized technical drivers are as follows a) Metadata refinement and extraction of attachments from eLN experiment pdf files into EDB S3 Refine Bucket from LOXO-Signals and DICE eLN experiment data available in EDB S3 Raw Bucket. b) Automation and optimization of processes to increase efficiency."

# %%
def load_workbook(path):
    return openpyxl.load_workbook(path)

#Code for fetching the GenAI-based solution 

client = OpenAI(api_key="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")

# Set up your OpenAI API key
#openai.api_key = "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"


# Define the previous conversation history
conversation_history = [
    {"role": "system", "content": "You are an assistant who is helping the user draft responses for a service now Change Request"},  # Initial system prompt
    {"role": "user", "content": "EDB: M&A eLN Experiment Data Refinement - Extract attachments from experiment PDF Files and Experiment Metadata into EDB S3 Refine Bucket"},   # Example of a user's question
    {"role": "assistant", "content": "The development team will create a custom component to refine metadata and to extract the attachments from eLN experiment pdf files of LOXO-Signals and DICE available in the EDB S3 Raw Bucket into EDB S3 Refined Bucket."} , # Assistant's response
]

conversation_history_two = [
    {"role": "system", "content": "You are an assistant who is helping the user draft responses for a service now Change Request"},  # Initial system prompt
    {"role": "user", "content": "EDB: M&A eLN Experiment Data Refinement - Extract attachments from experiment PDF Files and Experiment Metadata into EDB S3 Refine Bucket"},   # Example of a user's question
    {"role": "assistant", "content": data },  #Assistant's response
]

# Add the latest user prompt
#new_user_prompt = "EDB: Extract information from PDFs files stored in PPD folders and load data into the table"

def development_tab(sheet):

    if sheet['A2'].value == "Short Description":
        sheet['C2'].value = sheet['B2'].value


    if sheet['A4'].value == "1.Provide a detailed description of the change (change description should focus on component functionality not the project or solution):":
        new_user_prompt = sheet['B4'].value
        print("Printing value of Long Description Prompt", new_user_prompt)
        conversation_history.append({"role": "user", "content": new_user_prompt})
        chat_completion = client.chat.completions.create(messages= conversation_history,model="gpt-3.5-turbo")
        print(chat_completion.choices[0].message.content) 
        sheet['C4'].value = chat_completion.choices[0].message.content

    if sheet['A8'].value == "1.Describe the business and technical drivers for implementing the change":
        new_user_prompt_two = sheet['B8'].value
        print("Printing value of Business and Technical drivers", new_user_prompt_two)
        conversation_history_two.append({"role": "user", "content": new_user_prompt_two})
        chat_completion_two = client.chat.completions.create(messages= conversation_history_two,model="gpt-3.5-turbo")
        print(chat_completion_two.choices[0].message.content) 
        sheet['C8'].value = chat_completion_two.choices[0].message.content

    if sheet['A9'].value == "a.Is this a new custom component (Yes/No):":
        if sheet['B9'].value == "Yes":
            sheet['C9'].value == "Yes, This is a new custom component" 
        else:
            sheet['C9'].value == "No, this is not a new custom component"


    # Extracting information from cell B12 
    extracting_info = sheet['B12'].value
    Yes_or_No1 = extracting_info.split(",")[0].strip()
    comments = extracting_info.split(",")[1].strip()

    if sheet['A12'].value == "1.Is new code/configuration being developed or is current code being update?":
        if Yes_or_No1 == "Yes":
            sheet['C12'] = f'Yes, based on discussion with business we came to the conclusion that a new custom component needs to be built for "{comments}"'
        elif Yes_or_No1 == "updated":
            sheet['C12'] = f'After discussions with Business, it was determined that the custom component needs to be updated "{comments}"'
        else:
            print("Input should be yes comments or Updated comments")

    # Extracting information from cell B14
    demo = sheet['B14'].value
    Yes_or_No = demo.split(",")[0].strip()
    print(Yes_or_No, "First Yes/no")
    reviewer_name = demo.split(",")[1].strip()
    print(reviewer_name, "Reviewer name") 

    if sheet['A14'].value == "2.Source code reviews will be executed and the  executed source code review information will be documented in the Development Execution Notes.":
        if Yes_or_No == "Yes":
            sheet['c14'] = f'Source Code review will be done by reviewer mentioned below. Reviewer (ITSME) - {reviewer_name}'

    # Extracting information from cell B16
    getting_value = sheet['B16'].value
    Yes_or_No_info = getting_value.split()[0].strip()
    print(Yes_or_No_info)
    link = getting_value.split()[1].strip() if len(getting_value.split()) > 1 else ""
    print(link)

    if sheet['A15'].value == "3.List any validation artifacts to be created/modified. ":
        if sheet['A16'].value == "a.Are Requirements being created/updated (Yes/No)?":
            print('yes I have entered this loop')
            if Yes_or_No_info == "Yes":
                print("This is correct") 
                sheet['C16'] = f"Yes, Component requirements will be newly created. Data requirements will be newly created. {link}"
            elif Yes_or_No_info == "No":
                sheet['C16'] = f'No, Component requirements will be updated. Data requirements will be updated.'
            
            

    if sheet['A18'].value == "b.Is a Component Design Artifact being created/updated (Yes/No)?":
        if sheet['B18'].value == 'Yes':
            print("yes, entered this loop")
            sheet['C18'] = "Yes, new Component Design Artifact will be created"
        elif sheet['B18'].value == 'No':
            sheet['C18'] = 'No, existing Component Design Artifact will be updated."comments"'

    if sheet['A20'].value == "c.Is an EDB Application Security Plan Custom Component Attachment being created /updated (Yes/No)?  ":
        if sheet['B20'].value == 'Yes':
            sheet['C20'] = "Yes, new EDB Application Security Plan will be created for the new custom component"
        elif sheet['B20'].value == 'No':
            sheet['C20'] = 'No new roles added or modified. Hence there is no update in existing Security Plan'

    if sheet['A22'].value == "d.Is the EDB Security Plan being updated (Yes/No)?":
        if sheet['B22'].value == 'Yes':
            sheet['C22'] = "Yes, EDB Security Plan will be updated."
        elif sheet['B22'].value == 'No':
            sheet['C22'] = 'No. New EDB Security Plan will be created'

    if sheet['A24'].value == "e.Are Test Scripts/Cases being created/updated (Yes/No)?":
        print("Yes Entered Loop in A24")
        if sheet['B24'].value == 'Yes':
            sheet['C24'] = "Yes, new Test Scripts/Cases will be created."
        elif sheet['B24'].value == 'No,"comments"':
            sheet['C24'] = 'No, new Test Scripts/Cases will not be created, "comments"'

    if sheet['A26'].value == "f.Is a Requirements Traceability Matrix (RTM) being created/updated (Yes/No)?":
        if sheet['B26'].value == 'Yes':
            sheet['C26'] = "Yes, new Requirements Traceability Matrix (RTM) will be created."
        elif sheet['B26'].value == 'No':
            sheet['C26'] = 'No, new Requirements Traceability Matrix (RTM) will not be created/updated'


def deployment_tab(sheet):
# placeholder feature
    if sheet['A31'].value =="Deployment Plan":
        if sheet['A32'].value=="1.Is this change an emergency? If yes, record names of persons agreeing to implement (Technical Approver), method of agreement,date of agreement,and justification":
            if sheet['B32'].value == "No":
                 sheet['C32']='No, This is not an emergency change.'
            elif sheet['B32'].value == "Yes":
                    sheet['C32']="Yes, this is an emergency change.<placeholder>"
 
    user_input_values = sheet['B34'].value
    print(user_input_values)
    placeholder_Git_repo = user_input_values.split(",")[0].strip()
    place_holder_operation_team = user_input_values.split(",")[1].strip()
    if sheet['A34'].value =="2.Document implementation plan/actions, including required interactions (such as user training) with associated change requests, sites or business customers. Detail how the code is to be installed into the production environment including the deployment to production process":
        sheet['C34']=f" Pull requests in GitHub will be raised to merge code components from qa to the main branch.-GitHub repository: '{placeholder_Git_repo}' EDB DevOps Team will merge the code from qa to the main branch."
 
 
    user_input = sheet['B35'].value
    placeholder = user_input.split(",")[0].strip()
    development_team_member = user_input.split(",")[1].strip()
 
    if sheet['A35'].value =="3.Parties involved in the deployment.":
        print("Print value of cell B35", user_input)
        user_input = user_input.split(",")
        trimmed_elements = [i.strip() for i in user_input]
        result = ", ".join(trimmed_elements)
        sheet['C35']=f"EDB DevOps Team & {result} will be involved in deployment."
 
 
   
    user_input_demo = sheet['B36'].value
    yes_or_no_details = user_input_demo.split(",")[0].strip()
    placeholder_for_CTASK_No = user_input_demo.split(",")[1].strip()
    if sheet['A36'].value=="4.Verify the metadata values in production against the values documented in the Data Inventory.Document the results of the verification in the related CTASK and document the CTASK completion date in the Development Execution Notes.":
        if yes_or_no_details == "Yes":
            sheet['C36']=f"Yes, {placeholder_for_CTASK_No} will be verified and the CTASK completion date will be documented in Dev Execution Notes."
        if yes_or_no_details == "No":
            sheet['C36']="No, <Add reason, can be parsed from the reason given in Development Plan>"
 
    if sheet['A38'].value=="5.Is this the deployment of new component (Yes/No) ? ":
        sheet['B38'].value = sheet['B38'].value.strip()
        print("yes I've entered the loop in A38")
        if sheet['B38'].value=="Yes":
            sheet['C38']='Yes, this change is for deploying a new component'
        elif sheet['B38'].value=="No":
            sheet['C38']="N/A"       

    # Extracting Yes, <placeholder>, id
    user_input = sheet['B28'].value

    # Ensure user_input has at least two comma-separated values
    response = user_input.split(",")[0].strip()
    placeholder = user_input.split(",")[1].strip()
    metadata_id = user_input.split(",")[2].strip()

    if sheet['A28'].value == "4.Does the data inventory need to be updated (Yes/No)?":
        if response == "Yes":
            sheet['C28'] = f"Yes, {placeholder} will be catalogued and managed within metadata manager, metadata manager: {metadata_id}."
        elif response == "No":
            sheet['C28'] =  f"No, Since no new attributes are part of this release, Metadata Manager entries don't need to be created."

    if sheet['A30'].value == "5.Business QA Agreement to Develop (Only components requiring quality oversight)":
        sheet['C30'] = f" \"The BQA name, {sheet['B30'].value} and Date of Approval will be added in Development Execution Notes\". "

def save_workbook(workbook, output_file):
    if os.path.exists(output_file):
        os.remove(output_file)
    workbook.save(output_file)

def main():
    try:
        path = 'C:/Users/shivghosh/Downloads/CR Automation Template (yes) 1 1 (1).xlsx'
        output_file = 'C:/Users/shivghosh/Downloads/CR Automation Template (no)_output.xlsx'

        workbook = load_workbook(path)
        sheet = workbook['Iterable Sheet']

        development_tab(sheet)
        deployment_tab(sheet)
        save_workbook(workbook, output_file)
        print(f"Workbook saved successfully as {output_file}")
    except Exception as e:
        print(f"An error occurred: {e}")

if __name__ == "__main__":
    main()
# Out:
# Printing value of Long Description Prompt to ingest ppd metadata and pdfs from PPD Share point into EDB S3 Raw Bucket
# The development team will implement an ingestion process to extract metadata and PDFs from the PPD SharePoint repository and load them into the EDB S3 Raw Bucket for further processing.
# Printing value of Business and Technical drivers Bring PPD data available on PPD Sharepoint into EDB S3 Raw Bucket.
# The business driver is to integrate the PPD data available on PPD SharePoint into the EDB S3 Raw Bucket for centralized storage and access. The technical drivers include a) Extracting PPD data from SharePoint and transferring it securely to EDB S3 Raw Bucket. b) Ensuring data integrity and consistency during the transfer process.
# Yes First Yes/no
# Ivo R Bellu Reviewer name
# Yes
# www.jira.com
# yes I have entered this loop
# This is correct
# yes, entered this loop
# Yes Entered Loop in A24
#  mdids-edb-raw-refine,<place holder operation team>
# ...
